# %% [markdown]
# # [코로나 확진과 의약품 소모의 연관성]

# %% [markdown]
# *   기간: 2023-04-26 ~ yyyy-mm-dd (총 4일)
# *   리더: 이진호
# *   스탭:
# *   정의: 코로나 확진자와 의약품 소모량의 상관관계
# *   목적: 코로나 확진자가 많아질수록 의약품의 소모량이 얼마나 늘어나는지 확인하기 위해서.
# *   범위: 프로젝트의 수행범위를 기술합니다.

# %% [markdown]
# ## [할 일 목록]

# %% [markdown]
# ### [1일차]

# %% [markdown]
# #### 1.   **공공데이터 포털에서 코로나 확진자 데이터 가져오기.**

# %% [markdown]
# 필요할 경우 상세 설명을 기술합니다.

# %% [markdown]
# #### 2.   **'보건의료빅데이터개방시스템'에서 의약품 처방수와 판매량 데이터를 가져온다.**

# %% [markdown]
# 필요할 경우 상세 설명을 기술합니다.

# %% [markdown]
# #### 3.   코로나 확진자 데이터로 월별 확진자수를 구한다.

# %% [markdown]
# 보건의료빅데이터개방시스템이 파일을 xls 그리고 월별로만 제공하기 때문에.

# %% [markdown]
# #### 4.   코로나 확산전의 데이터로 의약품의 월별 평균 사용량을 구한다.

# %% [markdown]
# 의약품의 사용은 계절의 변화에 영향을 받기 때문에 이전의 데이터를 통해서 평균 사용량을 구하여 그것을 기준으로 잡는다.

# %% [markdown]
# #### 5.   확진자 증가수와 의약품 소모량 증가량을 구하여 비교한다.

# %% [markdown]
# 필요할 경우 상세 설명을 기술합니다.

# %% [markdown]
# ### [n일차]

# %% [markdown]
# #### 1.   첫 번째 우선순위의 작업을 기술합니다.

# %% [markdown]
# 필요할 경우 상세 설명을 기술합니다.

# %% [markdown]
# #### 2.   두 번째 우선순위의 작업을 기술합니다.

# %% [markdown]
# 필요할 경우 상세 설명을 기술합니다.

# %% [markdown]
# #### 3.   세 번째 우선순위의 작업을 기술합니다.

# %% [markdown]
# 필요할 경우 상세 설명을 기술합니다.

# %% [markdown]
# #### 4.   네 번째 우선순위의 작업을 기술합니다.

# %% [markdown]
# 필요할 경우 상세 설명을 기술합니다.

# %% [markdown]
# #### 5.   다섯 번째 우선순위의 작업을 기술합니다.

# %% [markdown]
# 필요할 경우 상세 설명을 기술합니다.

# %% [markdown]
# ## [이슈 항목]

# %% [markdown]
# ### 1.   ~~프로젝트 중 발생한 이슈 항목을 추가합니다.~~ <= 이슈를 해결한 항목은 취소선을 표시합니다.

# %% [markdown]
# ```
# def z_score(x, ddof=0):
#     return x - x.mean() / x.std(ddof=ddof)
# ```
# z_score 함수의 결과가 예상과 다른 결과를 반환함
# ```
# def z_score(x, ddof=0):
#     return (x - x.mean()) / x.std(ddof=ddof)
# ```
# ```x - x.mean()``` 연산에 괄호 ```( )```를 사용해 연산자 우선순위에 따른 부작용을 찾아 해결함

# %% [markdown]
# ### 2.   프로젝트 중 발생한 이슈 항목을 추가합니다.

# %% [markdown]
# 이슈 항목을 자세히 기술하고 이슈 해결이 완료되면 솔루션에 대한 설명을 기술합니다.

# %% [markdown]
# ### 3.   프로젝트 중 발생한 이슈 항목을 추가합니다.

# %% [markdown]
# 이슈 항목을 자세히 기술하고 이슈 해결이 완료되면 솔루션에 대한 설명을 기술합니다.

# %% [markdown]
# ### 4.   프로젝트 중 발생한 이슈 항목을 추가합니다.

# %% [markdown]
# 이슈 항목을 자세히 기술하고 이슈 해결이 완료되면 솔루션에 대한 설명을 기술합니다.

# %% [markdown]
# ### 5.   프로젝트 중 발생한 이슈 항목을 추가합니다.

# %% [markdown]
# 이슈 항목을 자세히 기술하고 이슈 해결이 완료되면 솔루션에 대한 설명을 기술합니다.
